# %%
import numpy as np
import pandas as pd
from pathlib import Path
import dask.dataframe as dd

# %%
ir_dd = dd.accessor

# %%
DATA_DIR = Path("../data/BDIR7R/")
dtset = (DATA_DIR / "synthetic")
dtset = dtset.as_posix()
# Out:
# '../data/BDIR7R/synthetic'

# %%
df = pd.read_csv("../data/synthetic/synthetic_bdhs_10k.csv")
df.describe()
# Out:
#                 age  education_years   anc_visits  skilled_delivery  \
# count  10000.000000     10000.000000  10000.00000      10000.000000
# mean      31.071200         4.137200      3.89960          0.754400
# std        9.974772         2.814279      2.06832          0.430464
# min       15.000000         0.000000      0.00000          0.000000
# 25%       22.000000         1.000000      3.00000          1.000000
# 50%       31.000000         4.000000      4.00000          1.000000
# 75%       40.000000         6.000000      5.00000          1.000000
# max       49.000000        12.000000     10.00000          1.000000
#
#        facility_delivery  complications        sys_bp       dia_bp  \
# count       10000.000000   10000.000000  10000.000000  10000.00000
# mean            0.773700       0.239700    126.148700     81.74150
# std             0.418456       0.426922     13.719957     10.65592
# min             0.000000       0.000000     80.000000     50.00000
# ...

# %%
df.head()
# Out:
#    age  education_years wealth_quintile urban_rural  anc_visits  \
# 0   36                4         poorest       urban           5
# 1   16                4         richest       urban           3
# 2   32                5         richest       urban           5
# 3   21                5          richer       rural           1
# 4   18                6          richer       rural           2
#
#    skilled_delivery  facility_delivery  complications  sys_bp  dia_bp  \
# 0                 1                  1              0   129.0    83.0
# 1                 1                  1              0   107.0    71.0
# 2                 1                  1              1   147.0    78.0
# 3                 1                  1              0   116.0    91.0
# 4                 1                  1              1   153.0    98.0
#
#    heart_rate  glucose  district_id  preeclampsia_risk  gdm_risk  high_risk
# 0        94.0    124.0           22                  0         0          0
# ...

# %%
# Out:
# ['calibration',
#  'clone',
#  'cluster',
#  'compose',
#  'config_context',
#  'covariance',
#  'cross_decomposition',
#  'datasets',
#  'decomposition',
#  'discriminant_analysis',
#  'dummy',
#  'ensemble',
#  'exceptions',
#  'experimental',
#  'externals',
#  'feature_extraction',
#  'feature_selection',
#  'frozen',
#  'gaussian_process',
#  'get_config',
#  'impute',
#  'inspection',
#  'isotonic',
#  'kernel_approximation',
#  'kernel_ridge',
#  'linear_model',
#  'manifold',
#  'metrics',
#  'mixture',
#  'model_selection',
#  'multiclass',
#  'multioutput',
#  'naive_bayes',
#  'neighbors',
#  'neural_network',
#  'pipeline',
#  'preprocessing',
#  'random_projection',
#  'semi_supervised',
#  'set_config',
#  'show_versions',
#  'svm',
#  'tree']

# %%
dir(sklearn.manifold)
# Out:
# ['ClassicalMDS',
#  'Isomap',
#  'LocallyLinearEmbedding',
#  'MDS',
#  'SpectralEmbedding',
#  'TSNE',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_barnes_hut_tsne',
#  '_classical_mds',
#  '_isomap',
#  '_locally_linear',
#  '_mds',
#  '_spectral_embedding',
#  '_t_sne',
#  '_utils',
#  'locally_linear_embedding',
#  'smacof',
#  'spectral_embedding',
#  'trustworthiness']
